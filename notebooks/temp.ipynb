# %%
"Hello World"
# Out:
# 'Hello World'

# %%
from datasets import load_dataset, Features, Value

features = Features({
    "Institute": Value("string"),
    "Academic Program Name": Value("string"),
    "Quota": Value("string"),
    "Seat Type": Value("string"),
    "Gender": Value("string"),
    "Opening Rank": Value("int64"),
    "Closing Rank": Value("int64"),
    "Year": Value("int64"),
    "Round": Value("int64"),
})

dataset = load_dataset(
    "VashuTheGreat2/JOSAA_COUNSELLING_DATASET",
    data_files="*.csv",
    features=features
)

# dataset.save_to_disk("data2/")
# Out:
# Saving the dataset (1/1 shards): 100%|██████████| 523387/523387 [00:00<00:00, 1007632.45 examples/s]

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['Institute', 'Academic Program Name', 'Quota', 'Seat Type', 'Gender', 'Opening Rank', 'Closing Rank', 'Year', 'Round'],
#         num_rows: 523387
#     })
# })

# %%
dataset['train'].to_pandas()
# Out:
#                                                 Institute  ... Round
# 0              Indian Institute of Technology Bhubaneswar  ...     1
# 1              Indian Institute of Technology Bhubaneswar  ...     1
# 2              Indian Institute of Technology Bhubaneswar  ...     1
# 3              Indian Institute of Technology Bhubaneswar  ...     1
# 4              Indian Institute of Technology Bhubaneswar  ...     1
# ...                                                   ...  ...   ...
# 523382  Shri G. S. Institute of Technology and Science...  ...     6
# 523383  Shri G. S. Institute of Technology and Science...  ...     6
# 523384  Shri G. S. Institute of Technology and Science...  ...     6
# 523385  Shri G. S. Institute of Technology and Science...  ...     6
# 523386  Shri G. S. Institute of Technology and Science...  ...     6
#
# [523387 rows x 9 columns]
